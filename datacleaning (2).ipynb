# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# Use raw string (r) or escape backslashes for Windows file path
file_path = r"C:\Users\Sanjana Kumari\Downloads\glacier data.csv.csv"

# Read the CSV into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df.head()  # Display the first 5 rows
# Out:
#    Fjord_ID  Fjord_Latitude  Fjord_Longitude  Glacier_ID  \
# 0         1       69.911000       -22.817793       132.0
# 1         2       69.664454       -23.569006         NaN
# 2         3       69.522478       -24.032489       133.0
# 3         4       69.352949       -24.610384         NaN
# 4         5       69.243200       -25.100802       135.0
#
#    Glacier_Point_Latitude  Glacier_Point_Longitude  Fjord_Area_km2  \
# 0               69.964707               -22.883172          200.49
# 1                     NaN                      NaN          110.48
# 2               69.598531               -24.005461          117.62
# 3                     NaN                      NaN           99.88
# 4               69.234147               -25.466801          144.89
#
#    Fjord_Mouth_Length_km  MaxDepth_m_Bedmachine_v5  MeanDepth_m_Bedmachine_v5  \
# 0                  26.80                176.136276                  23.489177
# ...

# %%
# Display basic information about the dataset
print(df.info())

# Display the first few rows
print(df.head())

# Display basic statistics
print(df.describe())

print("Dataset loaded successfully.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 52 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Fjord_ID                                                         99 non-null     int64
#  1   Fjord_Latitude                                                   99 non-null     float64
#  2   Fjord_Longitude                                                  99 non-null     float64
#  3   Glacier_ID                                                       87 non-null     float64
#  4   Glacier_Point_Latitude                                           87 non-null     float64
#  5   Glacier_Point_Longitude                                          87 non-null     float64
#  6   Fjord_Area_km2                                                   99 non-null     float64
# ...

# %%
df.shape
# Out:
# (99, 52)

# %%
df.describe(include='all')
# Out:
#          Fjord_ID  Fjord_Latitude  Fjord_Longitude  Glacier_ID  \
# count   99.000000       99.000000        99.000000   87.000000
# unique        NaN             NaN              NaN         NaN
# top           NaN             NaN              NaN         NaN
# freq          NaN             NaN              NaN         NaN
# mean    27.111111       65.699720       -35.858188  220.931034
# std     13.211690        2.759182         6.136626  163.686015
# min      1.000000       60.486061       -43.533833  132.000000
# 25%     18.000000       63.245188       -41.494769  153.500000
# 50%     29.000000       66.083043       -36.952589  175.000000
# 75%     37.500000       68.327930       -32.205442  196.500000
# max     52.000000       69.911000       -22.817793  805.000000
#
#         Glacier_Point_Latitude  Glacier_Point_Longitude  Fjord_Area_km2  \
# count                87.000000                87.000000       99.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 52 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Fjord_ID                                                         99 non-null     int64
#  1   Fjord_Latitude                                                   99 non-null     float64
#  2   Fjord_Longitude                                                  99 non-null     float64
#  3   Glacier_ID                                                       87 non-null     float64
#  4   Glacier_Point_Latitude                                           87 non-null     float64
#  5   Glacier_Point_Longitude                                          87 non-null     float64
#  6   Fjord_Area_km2                                                   99 non-null     float64
# ...

# %%
# Check for missing values in the dataset
missing_values = df.isnull().sum()
df
# Out:
#     Fjord_ID  Fjord_Latitude  Fjord_Longitude  Glacier_ID  \
# 0          1       69.911000       -22.817793       132.0
# 1          2       69.664454       -23.569006         NaN
# 2          3       69.522478       -24.032489       133.0
# 3          4       69.352949       -24.610384         NaN
# 4          5       69.243200       -25.100802       135.0
# ..       ...             ...              ...         ...
# 94        48       61.088773       -43.016126         NaN
# 95        49       60.881241       -43.042911       202.0
# 96        50       60.792281       -43.107583       805.0
# 97        51       60.587100       -43.025529         NaN
# 98        52       60.486061       -43.533833         NaN
#
#     Glacier_Point_Latitude  Glacier_Point_Longitude  Fjord_Area_km2  \
# 0                69.964707               -22.883172          200.49
# 1                      NaN                      NaN          110.48
# ...

# %%
#display columns with missing values
missing_columns= missing_values[missing_values > 0]
print(missing_columns)
# Out:
# Glacier_ID                                                         12
# Glacier_Point_Latitude                                             12
# Glacier_Point_Longitude                                            12
# Mankoff_Glacier_ID                                                 32
# Fjord_Cumulative_Solid_Ice_Discharge_Gt_2015_2019                  21
# Fjord_Cumulative_Solid_Ice_Discharge_Error_Gt_2015_2019            21
# Fjord_Mean_Annual_Solid_Ice_Discharge_GtPerYr_2015_2019            21
# Fjord_Mean_Annual_Solid_Ice_Discharge_Error_GtPerYr_2015_2019      21
# Fjord_Mean_Hydroyear_Discharge_GtPerYr                             21
# Fjord_Mean_Hydroyear_Discharge_Error_GtPerYr                       21
# Fjord_Mean_Winter_Discharge_GtPerYr                                21
# Fjord_Mean_Winter_Discharge_Error_GtPerYr                          21
# Fjord_Mean_Spring_Discharge_GtPerYr                                21
# ...

# %%
# Handle missing values
# For simplicity, let's fill missing numeric values with the median and categorical with the mode
for column in df.columns:
    if df[column].dtype in ['float64', 'int64']:
        # Using loc to avoid chained assignment
        df.loc[:, column] = df[column].fillna(df[column].median())
    else:
        # Using loc to avoid chained assignment for non-numeric columns
        df.loc[:, column] = df[column].fillna(df[column].mode()[0])

# Verify that there are no more missing values
missing_values_after = df.isnull().sum().sum()
print("Total missing values after handling:", missing_values_after)
# Out:
# Total missing values after handling: 0

# %%
df = df.dropna()
df
# Out:
#     Fjord_ID  Fjord_Latitude  Fjord_Longitude  Glacier_ID  \
# 0          1       69.911000       -22.817793       132.0
# 1          2       69.664454       -23.569006       175.0
# 2          3       69.522478       -24.032489       133.0
# 3          4       69.352949       -24.610384       175.0
# 4          5       69.243200       -25.100802       135.0
# ..       ...             ...              ...         ...
# 94        48       61.088773       -43.016126       175.0
# 95        49       60.881241       -43.042911       202.0
# 96        50       60.792281       -43.107583       805.0
# 97        51       60.587100       -43.025529       175.0
# 98        52       60.486061       -43.533833       175.0
#
#     Glacier_Point_Latitude  Glacier_Point_Longitude  Fjord_Area_km2  \
# 0                69.964707               -22.883172          200.49
# 1                66.377950               -36.313473          110.48
# ...

# %%
print("Data cleaning, validation, and preprocessing completed.")
print("\
Dataset shape:", df.shape)
print("\
Column types:")
print(df.dtypes)

# Display the first few rows of the preprocessed dataset
print("\
First few rows of the preprocessed dataset:")
print(df.head())
# Out:
# Data cleaning, validation, and preprocessing completed.
# Dataset shape: (99, 52)
# Column types:
# Fjord_ID                                                             int64
# Fjord_Latitude                                                     float64
# Fjord_Longitude                                                    float64
# Glacier_ID                                                         float64
# Glacier_Point_Latitude                                             float64
# Glacier_Point_Longitude                                            float64
# Fjord_Area_km2                                                     float64
# Fjord_Mouth_Length_km                                              float64
# MaxDepth_m_Bedmachine_v5                                           float64
# MeanDepth_m_Bedmachine_v5                                          float64
# Depth_StdDev_m_Bedmachine_v5                                       float64
# ...

# %%
df.head()
# Out:
#    Fjord_ID  Fjord_Latitude  Fjord_Longitude  Glacier_ID  \
# 0         1       69.911000       -22.817793       132.0
# 1         2       69.664454       -23.569006       175.0
# 2         3       69.522478       -24.032489       133.0
# 3         4       69.352949       -24.610384       175.0
# 4         5       69.243200       -25.100802       135.0
#
#    Glacier_Point_Latitude  Glacier_Point_Longitude  Fjord_Area_km2  \
# 0               69.964707               -22.883172          200.49
# 1               66.377950               -36.313473          110.48
# 2               69.598531               -24.005461          117.62
# 3               66.377950               -36.313473           99.88
# 4               69.234147               -25.466801          144.89
#
#    Fjord_Mouth_Length_km  MaxDepth_m_Bedmachine_v5  MeanDepth_m_Bedmachine_v5  \
# 0                  26.80                176.136276                  23.489177
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for the plots
plt.style.use('default')

# Visualize distributions of key numerical features
numerical_features = ['Glacier_Mean_Summer_Discharge_GtPerYr', 'Glacier_Mean_Summer_Discharge_Error_GtPerYr', 'Glacier_Mean_Autumn_Discharge_GtPerYr','Cumulative_FWF_m3_MAR','AnnualMean_FWF_m3_MAR','Mean_Winter_FWF_m3_MAR','Mean_Spring_FWF_m3_MAR','Glacier_Point_Latitude','Glacier_Point_Longitude']

fig, axes = plt.subplots(3, 3, figsize=(20, 20))
axes = axes.flatten()

for i, feature in enumerate(numerical_features):
    sns.histplot(df[feature].dropna(), kde=True, ax=axes[i])
    axes[i].set_title(f'Distribution of {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Count')

plt.tight_layout()
plt.show()

# Analyze relationships between features
correlation_matrix = df[numerical_features].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Features')
plt.show()
print("EDA completed. Plots displayed in the notebook.")
# Out:
# EDA completed. Plots displayed in the notebook.

# %%
# Updated EDA Exploration Script
import matplotlib.pyplot as plt
import seaborn as sns

# Define the new numerical columns based on the provided column names
numerical_features = [
    'Glacier_Mean_Summer_Discharge_GtPerYr', 
    'Glacier_Mean_Summer_Discharge_Error_GtPerYr', 
    'Glacier_Mean_Autumn_Discharge_GtPerYr',
    'Cumulative_FWF_m3_MAR', 
    'AnnualMean_FWF_m3_MAR', 
    'Mean_Winter_FWF_m3_MAR', 
    'Mean_Spring_FWF_m3_MAR'
]

# Define new categorical columns for visualizations (use placeholders or relevant columns as needed)
categorical_features = ['Glacier_Point_Latitude', 'Glacier_Point_Longitude']

# 1. Pairplot to visualize relationships between numerical features
sns.pairplot(df[numerical_features])
plt.suptitle('Pairplot of Numerical Glacier Features', y=1.02)
plt.show()

# 2. Boxplot to identify outliers in numerical features
plt.figure(figsize=(15, 10))
sns.boxplot(data=df[numerical_features])
plt.title('Boxplot of Numerical Glacier Features')
plt.xticks(rotation=45)
plt.show()

# 3. Countplot for the updated categorical features
for feature in categorical_features:
    plt.figure(figsize=(10, 5))
    sns.countplot(y=df[feature])
    plt.title(f'Countplot of {feature}')
    plt.show()

print("Additional EDA exploration completed.")
# Out:
# Additional EDA exploration completed.

# %%
df.head()
# Out:
#    Fjord_ID  Fjord_Latitude  Fjord_Longitude  Glacier_ID  \
# 0         1       69.911000       -22.817793       132.0
# 1         2       69.664454       -23.569006       175.0
# 2         3       69.522478       -24.032489       133.0
# 3         4       69.352949       -24.610384       175.0
# 4         5       69.243200       -25.100802       135.0
#
#    Glacier_Point_Latitude  Glacier_Point_Longitude  Fjord_Area_km2  \
# 0               69.964707               -22.883172          200.49
# 1               66.377950               -36.313473          110.48
# 2               69.598531               -24.005461          117.62
# 3               66.377950               -36.313473           99.88
# 4               69.234147               -25.466801          144.89
#
#    Fjord_Mouth_Length_km  MaxDepth_m_Bedmachine_v5  MeanDepth_m_Bedmachine_v5  \
# 0                  26.80                176.136276                  23.489177
# ...

# %%
# Export to CSV
# Assuming  cleaned data is in a DataFrame called 'cleaned_data'
df.to_csv(r'C:\Users\Sanjana Kumari\Downloads\glacier data.csv', index=False)

# %%
# Export to Excel
# Export DataFrame to Excel
df.to_excel(r'C:\Users\Sanjana Kumari\Downloads\glacier_data.xlsx', index=False)
